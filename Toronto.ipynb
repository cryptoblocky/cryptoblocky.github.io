# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# In this project we explore, segment, and cluster the neighborhoods in the city of Toronto. Since the data is not available in the Internet on a simple presentation, we have to  scrape a Wikipedia page wrangle the data, clean it, and then read it into  a structured format.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %% [markdown]
# ### Scraping the Data
#
# Use the Notebook to build the code to scrape the following Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe like the one shown below:

# %%
toronto='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
df = pd.read_html(toronto, header=0)[0]

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### Eliminating cells with a borough that is Not assigned
#
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
df.drop(df[df['Borough']=="Not assigned"].index,axis=0, inplace=True)

# %% [markdown]
# ### Grouping by Postal Code
#
# More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.

# %%
df1=df.groupby('Postcode')['Neighbourhood'].agg(lambda x: ','.join(x)) 
df3=pd.DataFrame(df1)
df3.reset_index().head()
# Out:
#   Postcode                         Neighbourhood
# 0      M1B                         Rouge,Malvern
# 1      M1C  Highland Creek,Rouge Hill,Port Union
# 2      M1E       Guildwood,Morningside,West Hill
# 3      M1G                                Woburn
# 4      M1H                             Cedarbrae

# %%
df2=df.groupby('Postcode')['Borough'].unique()
df4=pd.DataFrame(df2)
df4.reset_index().head()

df4['Borough']=[df4['Borough'][i][0] for i in range(df4.shape[0])]
df4.reset_index().head()
# Out:
#   Postcode      Borough
# 0      M1B  Scarborough
# 1      M1C  Scarborough
# 2      M1E  Scarborough
# 3      M1G  Scarborough
# 4      M1H  Scarborough

# %%
df4['Neighbourhood']=df3['Neighbourhood']

# %%
df4.reset_index().head()
# Out:
#   Postcode      Borough                         Neighbourhood
# 0      M1B  Scarborough                         Rouge,Malvern
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill
# 3      M1G  Scarborough                                Woburn
# 4      M1H  Scarborough                             Cedarbrae

# %%
df4.loc[df4['Neighbourhood']=="Not assigned",'Neighbourhood']=df4.loc[df4['Neighbourhood']=="Not assigned",'Borough']

# %%
df4.reset_index().head()
# Out:
#   Postcode      Borough                         Neighbourhood
# 0      M1B  Scarborough                         Rouge,Malvern
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill
# 3      M1G  Scarborough                                Woburn
# 4      M1H  Scarborough                             Cedarbrae

# %%
df4.shape
# Out:
# (103, 2)

# %% [markdown]
# ### Including the Latitude and Longitude to the Dataframe
#
# Now in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.

# %%
coords=r'http://cocl.us/Geospatial_data'

# %%
coord_df=pd.read_csv(coords)

# %%
df4['Latitude']=coord_df['Latitude'].values
df4['Longitude']=coord_df['Longitude'].values

# %%
df4.reset_index().head()
# Out:
#   Postcode      Borough                         Neighbourhood   Latitude  \
# 0      M1B  Scarborough                         Rouge,Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3      M1G  Scarborough                                Woburn  43.770992
# 4      M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ### Explore and cluster the neighborhoods in Toronto.

# %%
import folium

CLIENT_ID = 'IVUX2ATVRIVIAT3MYAOI3BNB0N5X2BCPEGK3W0FCX5RNN1HN' # my Foursquare ID
CLIENT_SECRET = '1UKWCBE54WZK50IHDYJXAK3GJCXPGQELW5QE30LXCGRA4MG2' # my Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IVUX2ATVRIVIAT3MYAOI3BNB0N5X2BCPEGK3W0FCX5RNN1HN
# CLIENT_SECRET:1UKWCBE54WZK50IHDYJXAK3GJCXPGQELW5QE30LXCGRA4MG2

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
LIMIT=100
toronto_venues = getNearbyVenues(names=df4['Neighbourhood'],
                                   latitudes=df4['Latitude'],
                                   longitudes=df4['Longitude']
                                  )
# Out:
# Rouge,Malvern
# Highland Creek,Rouge Hill,Port Union
# Guildwood,Morningside,West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# East Birchmount Park,Ionview,Kennedy Park
# Clairlea,Golden Mile,Oakridge
# Cliffcrest,Cliffside,Scarborough Village West
# Birch Cliff,Cliffside West
# Dorset Park,Scarborough Town Centre,Wexford Heights
# Maryvale,Wexford
# Agincourt
# Clarks Corners,Sullivan,Tam O'Shanter
# Agincourt North,L'Amoreaux East,Milliken,Steeles East
# L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview,Henry Farm,Oriole
# Bayview Village
# Silver Hills,York Mills
# Newtonbrook,Willowdale
# Willowdale South
# York Mills West
# Willowdale West
# Parkwoods
# Don Mills North
# Flemingdon Park,Don Mills South
# Bathurst Manor,Downsview North,Wilson Heights
# Northwood Park,York University
# CFB Toronto,Downsview East
# Downsview West
# Downsview Central
# Downsview Northwest
# Victoria Village
# Woodbine Gardens,Parkview Hill
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# East Toronto
# The Danforth West,Riverdale
# The Beaches West,India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park,Summerhill East
# Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West
# Rosedale
# Cabbagetown,St. James Town
# Church and Wellesley
# Harbourfront,Regent Park
# Ryerson,Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide,King,Richmond
# Harbourfront East,Toronto Islands,Union Station
# Design Exchange,Toronto Dominion Centre
# Commerce Court,Victoria Hotel
# Bedford Park,Lawrence Manor East
# Roselawn
# Forest Hill North,Forest Hill West
# The Annex,North Midtown,Yorkville
# Harbord,University of Toronto
# Chinatown,Grange Park,Kensington Market
# CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place,Underground city
# Lawrence Heights,Lawrence Manor
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dovercourt Village,Dufferin
# Little Portugal,Trinity
# Brockton,Exhibition Place,Parkdale Village
# Downsview,North Park,Upwood Park
# Del Ray,Keelesdale,Mount Dennis,Silverthorn
# The Junction North,Runnymede
# High Park,The Junction South
# Parkdale,Roncesvalles
# Runnymede,Swansea
# Queen's Park
# Canada Post Gateway Processing Centre
# Business Reply Mail Processing Centre 969 Eastern
# Humber Bay Shores,Mimico South,New Toronto
# Alderwood,Long Branch
# The Kingsway,Montgomery Road,Old Mill North
# Humber Bay,King's Mill Park,Kingsway Park South East,Mimico NE,Old Mill South,The Queensway East,Royal York South East,Sunnylea
# Kingsway Park South West,Mimico NW,The Queensway West,Royal York South West,South of Bloor
# Islington Avenue
# Cloverdale,Islington,Martin Grove,Princess Gardens,West Deane Park
# Bloordale Gardens,Eringate,Markland Wood,Old Burnhamthorpe
# Humber Summit
# Emery,Humberlea
# Weston
# Westmount
# Kingsview Village,Martin Grove Gardens,Richview Gardens,St. Phillips
# Albion Gardens,Beaumond Heights,Humbergate,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown
# Northwest

# %%
toronto_venues.groupby('Neighbourhood').count().head()
# Out:
#                                                     Neighbourhood Latitude  \
# Neighbourhood
# Adelaide,King,Richmond                                                 100
# Agincourt                                                                4
# Agincourt North,L'Amoreaux East,Milliken,Steele...                       2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...                       9
# Alderwood,Long Branch                                                    8
#
#                                                     Neighbourhood Longitude  \
# Neighbourhood
# Adelaide,King,Richmond                                                  100
# Agincourt                                                                 4
# Agincourt North,L'Amoreaux East,Milliken,Steele...                        2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...                        9
# Alderwood,Long Branch                                                     8
#
#                                                     Venue  Venue Latitude  \
# Neighbourhood
# Adelaide,King,Richmond                                100             100
# Agincourt                                               4               4
# Agincourt North,L'Amoreaux East,Milliken,Steele...      2               2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...      9               9
# Alderwood,Long Branch                                   8               8
#
#                                                     Venue Longitude  \
# Neighbourhood
# Adelaide,King,Richmond                                          100
# Agincourt                                                         4
# Agincourt North,L'Amoreaux East,Milliken,Steele...                2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...                9
# Alderwood,Long Branch                                             8
#
#                                                     Venue Category
# Neighbourhood
# Adelaide,King,Richmond                                         100
# Agincourt                                                        4
# Agincourt North,L'Amoreaux East,Milliken,Steele...               2
# Albion Gardens,Beaumond Heights,Humbergate,Jame...               9
# Alderwood,Long Branch                                            8

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 272 uniques categories.

# %% [markdown]
# #### Encoding the variables

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighbourhood']:
    #print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    #print(
    temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues)
   # print('\n')

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                        Neighbourhood 1st Most Common Venue  \
# 0                             Adelaide,King,Richmond           Coffee Shop
# 1                                          Agincourt                Lounge
# 2  Agincourt North,L'Amoreaux East,Milliken,Steel...            Playground
# 3  Albion Gardens,Beaumond Heights,Humbergate,Jam...           Pizza Place
# 4                              Alderwood,Long Branch           Pizza Place
#
#   2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café                        Bar            Steakhouse
# 1        Breakfast Spot  Latin American Restaurant          Skating Rink
# 2                  Park                Yoga Studio             Drugstore
# 3              Pharmacy                Video Store        Sandwich Place
# 4              Pharmacy                        Pub                   Gym
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0      Sushi Restaurant       Thai Restaurant                 Hotel
# 1   Dumpling Restaurant        Discount Store               Dog Run
# 2    Dim Sum Restaurant                 Diner        Discount Store
# 3            Beer Store   Fried Chicken Joint  Fast Food Restaurant
# 4           Coffee Shop        Sandwich Place          Skating Rink
#
#   8th Most Common Venue   9th Most Common Venue 10th Most Common Venue
# 0        Cosmetics Shop              Restaurant    American Restaurant
# 1      Doner Restaurant              Donut Shop              Drugstore
# 2               Dog Run        Doner Restaurant             Donut Shop
# 3         Grocery Store  Gluten-free Restaurant          Deli / Bodega
# 4          Dessert Shop      Dim Sum Restaurant                  Diner

# %% [markdown]
# ### K Clusters

# %%
# set number of clusters
kclusters = 7

toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([6, 6, 3, 6, 0, 6, 6, 6, 6, 6], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df4

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-a4e019f47dcb> in <module>
#       1 # add clustering labels
# ----> 2 neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
#       3
#       4 toronto_merged = dft
#       5
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
#    1151         if not isinstance(loc, int):
#
# ValueError: cannot insert Cluster Labels, already exists

# %%
toronto_merged.reset_index()
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# 30       M3K        North York
# 31       M3L        North York
# 32       M3M        North York
# 33       M3N        North York
# 34       M4A        North York
# 35       M4B         East York
# 36       M4C         East York
# 37       M4E      East Toronto
# 38       M4G         East York
# 39       M4H         East York
# 40       M4J         East York
# 41       M4K      East Toronto
# 42       M4L      East Toronto
# 43       M4M      East Toronto
# 44       M4N   Central Toronto
# 45       M4P   Central Toronto
# 46       M4R   Central Toronto
# 47       M4S   Central Toronto
# 48       M4T   Central Toronto
# 49       M4V   Central Toronto
# 50       M4W  Downtown Toronto
# 51       M4X  Downtown Toronto
# 52       M4Y  Downtown Toronto
# 53       M5A  Downtown Toronto
# 54       M5B  Downtown Toronto
# 55       M5C  Downtown Toronto
# 56       M5E  Downtown Toronto
# 57       M5G  Downtown Toronto
# 58       M5H  Downtown Toronto
# 59       M5J  Downtown Toronto
# 60       M5K  Downtown Toronto
# 61       M5L  Downtown Toronto
# 62       M5M        North York
# 63       M5N   Central Toronto
# 64       M5P   Central Toronto
# 65       M5R   Central Toronto
# 66       M5S  Downtown Toronto
# 67       M5T  Downtown Toronto
# 68       M5V  Downtown Toronto
# 69       M5W  Downtown Toronto
# 70       M5X  Downtown Toronto
# 71       M6A        North York
# 72       M6B        North York
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude  \
# 0                                        Rouge,Malvern  43.806686 -79.194353
# 1                 Highland Creek,Rouge Hill,Port Union  43.784535 -79.160497
# 2                      Guildwood,Morningside,West Hill  43.763573 -79.188711
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6            East Birchmount Park,Ionview,Kennedy Park  43.727929 -79.262029
# 7                        Clairlea,Golden Mile,Oakridge  43.711112 -79.284577
# 8        Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 9                           Birch Cliff,Cliffside West  43.692657 -79.264848
# 10   Dorset Park,Scarborough Town Centre,Wexford He...  43.757410 -79.273304
# 11                                    Maryvale,Wexford  43.750072 -79.295849
# 12                                           Agincourt  43.794200 -79.262029
# 13               Clarks Corners,Sullivan,Tam O'Shanter  43.781638 -79.304302
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.815252 -79.284577
# 15                                     L'Amoreaux West  43.799525 -79.318389
# 16                                         Upper Rouge  43.836125 -79.205636
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                          Fairview,Henry Farm,Oriole  43.778517 -79.346556
# 19                                     Bayview Village  43.786947 -79.385975
# 20                             Silver Hills,York Mills  43.757490 -79.374714
# 21                              Newtonbrook,Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                     Flemingdon Park,Don Mills South  43.725900 -79.340923
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.754328 -79.442259
# 29                      Northwood Park,York University  43.767980 -79.487262
# 30                          CFB Toronto,Downsview East  43.737473 -79.464763
# 31                                      Downsview West  43.739015 -79.506944
# 32                                   Downsview Central  43.728496 -79.495697
# 33                                 Downsview Northwest  43.761631 -79.520999
# 34                                    Victoria Village  43.725882 -79.315572
# 35                      Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# 36                                    Woodbine Heights  43.695344 -79.318389
# 37                                         The Beaches  43.676357 -79.293031
# 38                                             Leaside  43.709060 -79.363452
# 39                                    Thorncliffe Park  43.705369 -79.349372
# 40                                        East Toronto  43.685347 -79.338106
# 41                         The Danforth West,Riverdale  43.679557 -79.352188
# 42                       The Beaches West,India Bazaar  43.668999 -79.315572
# 43                                     Studio District  43.659526 -79.340923
# 44                                       Lawrence Park  43.728020 -79.388790
# 45                                    Davisville North  43.712751 -79.390197
# 46                                  North Toronto West  43.715383 -79.405678
# 47                                          Davisville  43.704324 -79.388790
# 48                          Moore Park,Summerhill East  43.689574 -79.383160
# 49   Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 50                                            Rosedale  43.679563 -79.377529
# 51                          Cabbagetown,St. James Town  43.667967 -79.367675
# 52                                Church and Wellesley  43.665860 -79.383160
# 53                            Harbourfront,Regent Park  43.654260 -79.360636
# 54                             Ryerson,Garden District  43.657162 -79.378937
# 55                                      St. James Town  43.651494 -79.375418
# 56                                         Berczy Park  43.644771 -79.373306
# 57                                  Central Bay Street  43.657952 -79.387383
# 58                              Adelaide,King,Richmond  43.650571 -79.384568
# 59     Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 60             Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 61                       Commerce Court,Victoria Hotel  43.648198 -79.379817
# 62                    Bedford Park,Lawrence Manor East  43.733283 -79.419750
# 63                                            Roselawn  43.711695 -79.416936
# 64                  Forest Hill North,Forest Hill West  43.696948 -79.411307
# 65                   The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 66                       Harbord,University of Toronto  43.662696 -79.400049
# 67             Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 68   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
# 69                     Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 70               First Canadian Place,Underground city  43.648429 -79.382280
# 71                     Lawrence Heights,Lawrence Manor  43.718518 -79.464763
# 72                                           Glencairn  43.709577 -79.445073
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.689026 -79.453512
# 75                                            Christie  43.669542 -79.422564
# 76                         Dovercourt Village,Dufferin  43.669005 -79.442259
# 77                             Little Portugal,Trinity  43.647927 -79.419750
# 78          Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 79                    Downsview,North Park,Upwood Park  43.713756 -79.490074
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.691116 -79.476013
# 81                        The Junction North,Runnymede  43.673185 -79.487262
# 82                        High Park,The Junction South  43.661608 -79.464763
# 83                               Parkdale,Roncesvalles  43.648960 -79.456325
# 84                                   Runnymede,Swansea  43.651571 -79.484450
# 85                                        Queen's Park  43.662301 -79.389494
# 86               Canada Post Gateway Processing Centre  43.636966 -79.615819
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88          Humber Bay Shores,Mimico South,New Toronto  43.605647 -79.501321
# 89                               Alderwood,Long Branch  43.602414 -79.543484
# 90         The Kingsway,Montgomery Road,Old Mill North  43.653654 -79.506944
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...  43.636258 -79.498509
# 92   Kingsway Park South West,Mimico NW,The Queensw...  43.628841 -79.520999
# 93                                    Islington Avenue  43.667856 -79.532242
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...  43.650943 -79.554724
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643515 -79.577201
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                     Emery,Humberlea  43.724766 -79.532242
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.696319 -79.532242
# 100  Kingsview Village,Martin Grove Gardens,Richvie...  43.688905 -79.554724
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.739416 -79.588437
# 102                                          Northwest  43.706748 -79.594054
#
#      Cluster Labels   1st Most Common Venue       2nd Most Common Venue  \
# 0               6.0    Fast Food Restaurant         Dumpling Restaurant
# 1               2.0                     Bar                 Yoga Studio
# 2               6.0      Mexican Restaurant                 Pizza Place
# 3               0.0             Coffee Shop                    Pharmacy
# 4               6.0        Hakka Restaurant          Athletics & Sports
# 5               6.0              Playground           Convenience Store
# 6               0.0        Department Store                 Coffee Shop
# 7               6.0                  Bakery                    Bus Line
# 8               6.0     American Restaurant                       Motel
# 9               6.0         College Stadium                Skating Rink
# 10              6.0       Indian Restaurant          Light Rail Station
# 11              6.0          Breakfast Spot               Shopping Mall
# 12              6.0                  Lounge              Breakfast Spot
# 13              6.0             Pizza Place        Fast Food Restaurant
# 14              3.0              Playground                        Park
# 15              6.0    Fast Food Restaurant          Chinese Restaurant
# 16              NaN                     NaN                         NaN
# 17              6.0                 Dog Run          Athletics & Sports
# 18              6.0          Clothing Store        Fast Food Restaurant
# 19              6.0                    Café                        Bank
# 20              4.0               Cafeteria         Dumpling Restaurant
# 21              1.0                     Gym                 Yoga Studio
# 22              6.0        Ramen Restaurant                 Coffee Shop
# 23              3.0             Flower Shop                        Bank
# 24              0.0             Pizza Place              Discount Store
# 25              3.0                    Park                    Bus Stop
# 26              6.0    Gym / Fitness Center                        Café
# 27              6.0                     Gym                 Coffee Shop
# 28              6.0             Coffee Shop                   Pet Store
# 29              6.0      Falafel Restaurant      Furniture / Home Store
# 30              3.0                 Airport                        Park
# 31              6.0           Grocery Store                        Bank
# 32              6.0            Home Service            Business Service
# 33              6.0            Liquor Store              Discount Store
# 34              0.0            Hockey Arena  Financial or Legal Service
# 35              6.0    Fast Food Restaurant                 Pizza Place
# 36              6.0                Pharmacy                        Park
# 37              6.0                   Trail           Health Food Store
# 38              6.0             Coffee Shop         Sporting Goods Shop
# 39              6.0       Indian Restaurant                Burger Joint
# 40              3.0                    Park                 Coffee Shop
# 41              6.0        Greek Restaurant                 Coffee Shop
# 42              6.0                    Park              Sandwich Place
# 43              6.0                    Café                 Coffee Shop
# 44              3.0                    Park                 Swim School
# 45              6.0                     Gym                        Park
# 46              6.0          Clothing Store         Sporting Goods Shop
# 47              6.0             Pizza Place              Sandwich Place
# 48              1.0                     Gym                 Yoga Studio
# 49              6.0             Coffee Shop                         Pub
# 50              3.0                    Park                  Playground
# 51              6.0             Pizza Place                        Café
# 52              6.0             Coffee Shop         Japanese Restaurant
# 53              6.0             Coffee Shop                      Bakery
# 54              6.0          Clothing Store                 Coffee Shop
# 55              6.0             Coffee Shop                        Café
# 56              6.0             Coffee Shop                Cocktail Bar
# 57              6.0             Coffee Shop          Italian Restaurant
# 58              6.0             Coffee Shop                        Café
# 59              6.0             Coffee Shop                       Hotel
# 60              6.0             Coffee Shop                        Café
# 61              6.0             Coffee Shop                        Café
# 62              6.0             Coffee Shop          Italian Restaurant
# 63              6.0                  Garden                   Drugstore
# 64              6.0                   Trail            Sushi Restaurant
# 65              6.0          Sandwich Place                        Café
# 66              6.0                    Café                  Restaurant
# 67              6.0                    Café       Vietnamese Restaurant
# 68              6.0         Airport Service              Airport Lounge
# 69              6.0             Coffee Shop                  Restaurant
# 70              6.0             Coffee Shop                        Café
# 71              6.0  Furniture / Home Store           Accessories Store
# 72              6.0                     Pub         Japanese Restaurant
# 73              6.0                   Field                Hockey Arena
# 74              3.0                    Park               Women's Store
# 75              6.0           Grocery Store                        Café
# 76              6.0                  Bakery                 Supermarket
# 77              6.0                     Bar                 Coffee Shop
# 78              6.0             Coffee Shop              Breakfast Spot
# 79              6.0                  Bakery                        Park
# 80              6.0          Sandwich Place                         Bar
# 81              6.0           Grocery Store        Caribbean Restaurant
# 82              6.0      Mexican Restaurant             Thai Restaurant
# 83              6.0             Coffee Shop                   Gift Shop
# 84              6.0             Coffee Shop                        Café
# 85              0.0             Coffee Shop                        Park
# 86              6.0                   Hotel                 Coffee Shop
# 87              6.0      Light Rail Station               Auto Workshop
# 88              6.0                Pharmacy         American Restaurant
# 89              0.0             Pizza Place                    Pharmacy
# 90              3.0                    Park                       River
# 91              6.0          Baseball Field                        Pool
# 92              6.0           Grocery Store      Thrift / Vintage Store
# 93              NaN                     NaN                         NaN
# 94              NaN                     NaN                         NaN
# 95              6.0                Pharmacy                  Beer Store
# 96              0.0             Pizza Place                  Restaurant
# 97              5.0          Baseball Field                 Yoga Studio
# 98              3.0                    Park                 Yoga Studio
# 99              0.0             Pizza Place              Sandwich Place
# 100             6.0             Pizza Place           Mobile Phone Shop
# 101             6.0             Pizza Place                    Pharmacy
# 102             6.0               Drugstore         Rental Car Location
#
#           3rd Most Common Venue      4th Most Common Venue  \
# 0                         Diner             Discount Store
# 1           Dumpling Restaurant             Discount Store
# 2                Breakfast Spot          Electronics Store
# 3             Korean Restaurant        Dumpling Restaurant
# 4           Fried Chicken Joint                       Bank
# 5                   Yoga Studio        Dumpling Restaurant
# 6                   Bus Station         Chinese Restaurant
# 7          Fast Food Restaurant              Metro Station
# 8           Dumpling Restaurant                      Diner
# 9         General Entertainment                       Café
# 10       Thrift / Vintage Store         Chinese Restaurant
# 11                  Auto Garage  Middle Eastern Restaurant
# 12    Latin American Restaurant               Skating Rink
# 13          Fried Chicken Joint          Convenience Store
# 14                  Yoga Studio                  Drugstore
# 15                     Pharmacy             Breakfast Spot
# 16                          NaN                        NaN
# 17                  Golf Course                       Pool
# 18                  Coffee Shop                   Tea Room
# 19           Chinese Restaurant        Japanese Restaurant
# 20                        Diner             Discount Store
# 21          Dumpling Restaurant                      Diner
# 22                  Pizza Place                       Café
# 23                         Park          Convenience Store
# 24                  Coffee Shop                    Butcher
# 25            Food & Drink Shop                Yoga Studio
# 26         Caribbean Restaurant        Japanese Restaurant
# 27                   Beer Store         Dim Sum Restaurant
# 28           Frozen Yogurt Shop              Shopping Mall
# 29                          Bar             Massage Studio
# 30                  Yoga Studio        Dumpling Restaurant
# 31                         Park          Convenience Store
# 32               Baseball Field                 Food Truck
# 33                Grocery Store         Athletics & Sports
# 34                  Coffee Shop      Portuguese Restaurant
# 35                    Gastropub                  Pet Store
# 36                 Skating Rink                   Bus Stop
# 37                 Neighborhood                        Pub
# 38       Furniture / Home Store               Burger Joint
# 39                  Yoga Studio                       Bank
# 40            Convenience Store                Yoga Studio
# 41               Ice Cream Shop         Italian Restaurant
# 42                 Liquor Store          Fish & Chips Shop
# 43                       Bakery         Italian Restaurant
# 44                     Bus Line                Yoga Studio
# 45               Breakfast Spot             Sandwich Place
# 46                  Coffee Shop                Yoga Studio
# 47                 Dessert Shop           Sushi Restaurant
# 48          Dumpling Restaurant                      Diner
# 49                   Bagel Shop        American Restaurant
# 50                        Trail                Yoga Studio
# 51                  Coffee Shop         Italian Restaurant
# 52             Sushi Restaurant                 Restaurant
# 53                         Park                    Theater
# 54               Cosmetics Shop                       Café
# 55                   Restaurant                      Hotel
# 56               Farmers Market                       Café
# 57               Ice Cream Shop                       Café
# 58                          Bar                 Steakhouse
# 59                     Aquarium                       Café
# 60                        Hotel        American Restaurant
# 61                        Hotel                 Restaurant
# 62         Fast Food Restaurant             Sandwich Place
# 63           Dim Sum Restaurant                      Diner
# 64                Jewelry Store         Mexican Restaurant
# 65                  Coffee Shop                  Pet Store
# 66                          Bar         Italian Restaurant
# 67                          Bar                Coffee Shop
# 68             Sculpture Garden                      Plane
# 69                         Café                      Hotel
# 70                   Steakhouse                      Hotel
# 71          Arts & Crafts Store                Event Space
# 72                       Bakery                       Park
# 73                        Trail              Moving Target
# 74                       Market       Fast Food Restaurant
# 75                         Park                 Baby Store
# 76                     Pharmacy                Music Venue
# 77                   Restaurant                Men's Store
# 78                         Café               Climbing Gym
# 79   Construction & Landscaping           Basketball Court
# 80                   Restaurant             Discount Store
# 81            Convenience Store                   Bus Line
# 82                          Bar                       Café
# 83                    Bookstore              Movie Theater
# 84           Italian Restaurant           Sushi Restaurant
# 85                          Gym                      Diner
# 86                Burrito Place       Gym / Fitness Center
# 87                         Park                 Comic Shop
# 88         Fast Food Restaurant             Sandwich Place
# 89                          Pub                        Gym
# 90                   Smoke Shop                Yoga Studio
# 91   Construction & Landscaping                Yoga Studio
# 92                          Gym          Convenience Store
# 93                          NaN                        NaN
# 94                          NaN                        NaN
# 95                    Pet Store                Pizza Place
# 96          Empanada Restaurant                 Donut Shop
# 97          Dumpling Restaurant             Discount Store
# 98          Dumpling Restaurant                      Diner
# 99                 Intersection                Coffee Shop
# 100                    Bus Line                 Donut Shop
# 101                 Video Store             Sandwich Place
# 102                 Yoga Studio                      Diner
#
#            5th Most Common Venue      6th Most Common Venue  \
# 0                        Dog Run           Doner Restaurant
# 1                        Dog Run           Doner Restaurant
# 2                 Medical Center        Rental Car Location
# 3                          Diner             Discount Store
# 4                         Bakery       Caribbean Restaurant
# 5                          Diner             Discount Store
# 6                    Yoga Studio                  Drugstore
# 7                    Bus Station               Soccer Field
# 8                 Discount Store                    Dog Run
# 9                     Donut Shop         Dim Sum Restaurant
# 10        Furniture / Home Store                  Pet Store
# 11                Sandwich Place                     Bakery
# 12           Dumpling Restaurant             Discount Store
# 13                  Noodle House         Italian Restaurant
# 14            Dim Sum Restaurant                      Diner
# 15                 Grocery Store          Electronics Store
# 16                           NaN                        NaN
# 17      Mediterranean Restaurant                Yoga Studio
# 18                        Bakery              Women's Store
# 19                   Yoga Studio             Discount Store
# 20                       Dog Run           Doner Restaurant
# 21                Discount Store                    Dog Run
# 22                    Restaurant           Sushi Restaurant
# 23   Eastern European Restaurant                    Dog Run
# 24                      Pharmacy              Grocery Store
# 25                     Drugstore             Discount Store
# 26              Basketball Court             Discount Store
# 27                   Supermarket                 Restaurant
# 28          Fast Food Restaurant             Sandwich Place
# 29          Caribbean Restaurant                Coffee Shop
# 30                         Diner             Discount Store
# 31                         Hotel              Shopping Mall
# 32                         Diner                    Dog Run
# 33           Dumpling Restaurant                    Dog Run
# 34           Dumpling Restaurant                      Diner
# 35          Gym / Fitness Center                   Bus Line
# 36                   Video Store                 Beer Store
# 37                    Donut Shop         Dim Sum Restaurant
# 38                Breakfast Spot               Liquor Store
# 39                           Gym               Liquor Store
# 40           Dumpling Restaurant             Discount Store
# 41        Furniture / Home Store             Cosmetics Shop
# 42              Sushi Restaurant             Ice Cream Shop
# 43           American Restaurant                Yoga Studio
# 44                     Drugstore             Discount Store
# 45                Clothing Store                      Hotel
# 46                    Restaurant        Rental Car Location
# 47                          Café                        Gym
# 48                Discount Store                    Dog Run
# 49                    Restaurant         Light Rail Station
# 50                     Drugstore         Dim Sum Restaurant
# 51                           Pub                     Bakery
# 52                       Gay Bar   Mediterranean Restaurant
# 53                Breakfast Spot                       Café
# 54                        Bakery                  Bookstore
# 55            Italian Restaurant             Clothing Store
# 56            Seafood Restaurant                Cheese Shop
# 57                  Burger Joint             Sandwich Place
# 58              Sushi Restaurant            Thai Restaurant
# 59                Scenic Lookout         Italian Restaurant
# 60                    Restaurant                  Gastropub
# 61           American Restaurant         Seafood Restaurant
# 62           Japanese Restaurant                  Juice Bar
# 63                Discount Store                    Dog Run
# 64                   Yoga Studio             Discount Store
# 65                  Burger Joint                Flower Shop
# 66           Japanese Restaurant                  Bookstore
# 67            Chinese Restaurant         Mexican Restaurant
# 68               Harbor / Marina                    Airport
# 69            Seafood Restaurant                   Beer Bar
# 70                    Restaurant         Seafood Restaurant
# 71                      Boutique      Vietnamese Restaurant
# 72                   Event Space       Ethiopian Restaurant
# 73                    Comic Shop               Dessert Shop
# 74              Greek Restaurant               Gourmet Shop
# 75                   Candy Store                      Diner
# 76                          Café  Middle Eastern Restaurant
# 77              Asian Restaurant      Vietnamese Restaurant
# 78                       Stadium              Burrito Place
# 79           Dumpling Restaurant             Discount Store
# 80             Convenience Store      Check Cashing Service
# 81                   Yoga Studio                  Drugstore
# 82          Fast Food Restaurant                     Bakery
# 83   Eastern European Restaurant         Italian Restaurant
# 84                         Diner                  Bookstore
# 85                   Yoga Studio              Burrito Place
# 86                Sandwich Place        American Restaurant
# 87                   Pizza Place           Recording Studio
# 88                   Flower Shop                       Café
# 89                   Coffee Shop             Sandwich Place
# 90                    Donut Shop         Dim Sum Restaurant
# 91           Dumpling Restaurant             Discount Store
# 92                Discount Store             Sandwich Place
# 93                           NaN                        NaN
# 94                           NaN                        NaN
# 95                   Coffee Shop          Convenience Store
# 96            Dim Sum Restaurant                      Diner
# 97                       Dog Run           Doner Restaurant
# 98                Discount Store                    Dog Run
# 99                Discount Store         Chinese Restaurant
# 100                        Diner             Discount Store
# 101                   Beer Store        Fried Chicken Joint
# 102               Discount Store                    Dog Run
#
#            7th Most Common Venue          8th Most Common Venue  \
# 0                     Donut Shop                      Drugstore
# 1                     Donut Shop                      Drugstore
# 2                   Intersection                    Yoga Studio
# 3                        Dog Run               Doner Restaurant
# 4                Thai Restaurant                         Lounge
# 5                        Dog Run               Doner Restaurant
# 6                        Dog Run               Doner Restaurant
# 7                   Intersection                           Park
# 8               Doner Restaurant                     Donut Shop
# 9                          Diner                 Discount Store
# 10         Vietnamese Restaurant         Gluten-free Restaurant
# 11   Eastern European Restaurant              Electronics Store
# 12                       Dog Run               Doner Restaurant
# 13                          Bank             Chinese Restaurant
# 14                Discount Store                        Dog Run
# 15                Cosmetics Shop                   Noodle House
# 16                           NaN                            NaN
# 17                     Drugstore                          Diner
# 18           Japanese Restaurant               Toy / Game Store
# 19                       Dog Run               Doner Restaurant
# 20                    Donut Shop                      Drugstore
# 21              Doner Restaurant                     Donut Shop
# 22                Sandwich Place                         Lounge
# 23              Doner Restaurant                     Donut Shop
# 24                  Gourmet Shop           Ethiopian Restaurant
# 25                       Dog Run               Doner Restaurant
# 26                       Dog Run               Doner Restaurant
# 27            Italian Restaurant            Japanese Restaurant
# 28                         Diner                     Restaurant
# 29            Miscellaneous Shop                     Donut Shop
# 30                       Dog Run               Doner Restaurant
# 31                     Drugstore                          Diner
# 32              Doner Restaurant                     Donut Shop
# 33              Doner Restaurant                     Donut Shop
# 34                Discount Store                        Dog Run
# 35                Breakfast Spot                   Intersection
# 36                Cosmetics Shop                    Curling Ice
# 37                         Diner                 Discount Store
# 38                 Smoothie Shop                     Restaurant
# 39                Discount Store                           Park
# 40                       Dog Run               Doner Restaurant
# 41                       Brewery                Bubble Tea Shop
# 42                  Intersection              Food & Drink Shop
# 43                Sandwich Place               Stationery Store
# 44                       Dog Run               Doner Restaurant
# 45             Food & Drink Shop                     Donut Shop
# 46                  Dessert Shop             Mexican Restaurant
# 47                   Coffee Shop             Italian Restaurant
# 48              Doner Restaurant                     Donut Shop
# 49           Fried Chicken Joint                     Sports Bar
# 50                         Diner                 Discount Store
# 51                    Restaurant                           Park
# 52               Bubble Tea Shop             Italian Restaurant
# 53                    Restaurant                            Pub
# 54                    Restaurant      Middle Eastern Restaurant
# 55                        Bakery                      Gastropub
# 56                        Bakery                     Steakhouse
# 57            Chinese Restaurant            Japanese Restaurant
# 58                         Hotel                 Cosmetics Shop
# 59           Fried Chicken Joint                     Restaurant
# 60                 Deli / Bodega             Italian Restaurant
# 61                     Gastropub                  Deli / Bodega
# 62                Breakfast Spot                   Liquor Store
# 63              Doner Restaurant                     Donut Shop
# 64                       Dog Run               Doner Restaurant
# 65             Indian Restaurant                   Liquor Store
# 66                        Bakery                 Sandwich Place
# 67                        Bakery  Vegetarian / Vegan Restaurant
# 68            Airport Food Court               Airport Terminal
# 69            Italian Restaurant                   Cocktail Bar
# 70                           Bar                         Bakery
# 71                   Coffee Shop             Miscellaneous Shop
# 72           Empanada Restaurant              Electronics Store
# 73                   Event Space           Ethiopian Restaurant
# 74                 Grocery Store           Ethiopian Restaurant
# 75             Convenience Store                    Coffee Shop
# 76                           Bar                           Bank
# 77       New American Restaurant                    Pizza Place
# 78                Sandwich Place                     Restaurant
# 79                       Dog Run               Doner Restaurant
# 80                   Yoga Studio                     Donut Shop
# 81                Discount Store                        Dog Run
# 82            Italian Restaurant                    Flea Market
# 83                       Dog Run                            Bar
# 84                           Bar              Food & Drink Shop
# 85            Italian Restaurant            Japanese Restaurant
# 86      Mediterranean Restaurant            Fried Chicken Joint
# 87                    Restaurant                        Butcher
# 88                    Restaurant                         Bakery
# 89                  Skating Rink                   Dessert Shop
# 90                         Diner                 Discount Store
# 91                       Dog Run               Doner Restaurant
# 92                  Burger Joint           Fast Food Restaurant
# 93                           NaN                            NaN
# 94                           NaN                            NaN
# 95                          Café                 Shopping Plaza
# 96                Discount Store                        Dog Run
# 97                    Donut Shop                      Drugstore
# 98              Doner Restaurant                     Donut Shop
# 99              Doner Restaurant                          Diner
# 100                      Dog Run               Doner Restaurant
# 101         Fast Food Restaurant                  Grocery Store
# 102             Doner Restaurant                     Donut Shop
#
#            9th Most Common Venue       10th Most Common Venue
# 0    Eastern European Restaurant                Women's Store
# 1    Eastern European Restaurant                        Field
# 2                 Discount Store                      Dog Run
# 3                     Donut Shop                    Drugstore
# 4                       Creperie             Cuban Restaurant
# 5                     Donut Shop                    Drugstore
# 6                     Donut Shop          Dumpling Restaurant
# 7              German Restaurant                 Dessert Shop
# 8                      Drugstore                  Yoga Studio
# 9                        Dog Run             Doner Restaurant
# 10              Doner Restaurant             Department Store
# 11           Dumpling Restaurant                        Diner
# 12                    Donut Shop                    Drugstore
# 13               Thai Restaurant                  Yoga Studio
# 14              Doner Restaurant                   Donut Shop
# 15                   Pizza Place                  Coffee Shop
# 16                           NaN                          NaN
# 17                Discount Store             Doner Restaurant
# 18                    Food Court               Cosmetics Shop
# 19                    Donut Shop                    Drugstore
# 20                   Yoga Studio              College Stadium
# 21                     Drugstore  Eastern European Restaurant
# 22           Japanese Restaurant                 Liquor Store
# 23                     Drugstore          Dumpling Restaurant
# 24             Electronics Store  Eastern European Restaurant
# 25                    Donut Shop          Dumpling Restaurant
# 26                    Donut Shop                    Drugstore
# 27                Sandwich Place          Sporting Goods Shop
# 28                 Deli / Bodega                  Supermarket
# 29                       Dog Run             Doner Restaurant
# 30                    Donut Shop                    Drugstore
# 31                Discount Store                      Dog Run
# 32                     Drugstore                  Yoga Studio
# 33                     Drugstore  Eastern European Restaurant
# 34              Doner Restaurant                   Donut Shop
# 35                          Bank           Athletics & Sports
# 36              Asian Restaurant                   Donut Shop
# 37                       Dog Run             Doner Restaurant
# 38                     Bike Shop                         Bank
# 39                      Pharmacy                  Pizza Place
# 40                    Donut Shop                    Drugstore
# 41                    Restaurant         Caribbean Restaurant
# 42            Italian Restaurant                          Pub
# 43                   Fish Market                    Bookstore
# 44                    Donut Shop          Dumpling Restaurant
# 45                Discount Store                      Dog Run
# 46                    Bagel Shop                        Diner
# 47                         Diner           Seafood Restaurant
# 48                     Drugstore  Eastern European Restaurant
# 49                   Supermarket             Sushi Restaurant
# 50                       Dog Run             Doner Restaurant
# 51             Convenience Store               Farmers Market
# 52                          Café                          Gym
# 53            Mexican Restaurant                  Yoga Studio
# 54              Ramen Restaurant           Italian Restaurant
# 55                Breakfast Spot               Cosmetics Shop
# 56                      Beer Bar                       Bistro
# 57                           Bar                          Spa
# 58                    Restaurant          American Restaurant
# 59                       Brewery                        Plaza
# 60                           Bar           Seafood Restaurant
# 61            Italian Restaurant                   Steakhouse
# 62                       Butcher             Sushi Restaurant
# 63                   Yoga Studio                 Dessert Shop
# 64                    Donut Shop                    Drugstore
# 65                     BBQ Joint               Cosmetics Shop
# 66                     Nightclub                     Beer Bar
# 67           Dumpling Restaurant                   Donut Shop
# 68                   Coffee Shop                          Bar
# 69                Farmers Market          Japanese Restaurant
# 70              Asian Restaurant          American Restaurant
# 71                Clothing Store                      Dog Run
# 72   Eastern European Restaurant          Dumpling Restaurant
# 73           Empanada Restaurant            Electronics Store
# 74           Empanada Restaurant            Electronics Store
# 75                    Restaurant                    Nightclub
# 76                       Brewery                  Art Gallery
# 77                          Café           Salon / Barbershop
# 78          Caribbean Restaurant                    Pet Store
# 79                    Donut Shop                    Drugstore
# 80                       Dog Run             Doner Restaurant
# 81              Doner Restaurant                   Donut Shop
# 82                     Speakeasy                Grocery Store
# 83                          Bank               Breakfast Spot
# 84                          Food          Indie Movie Theater
# 85                 Smoothie Shop           Seafood Restaurant
# 86     Middle Eastern Restaurant                   Donut Shop
# 87                 Burrito Place                   Skate Park
# 88           Fried Chicken Joint                  Pizza Place
# 89            Dim Sum Restaurant                        Diner
# 90                       Dog Run             Doner Restaurant
# 91                    Donut Shop                    Drugstore
# 92               Supplement Shop                       Bakery
# 93                           NaN                          NaN
# 94                           NaN                          NaN
# 95                  Liquor Store        General Entertainment
# 96              Doner Restaurant                    Drugstore
# 97   Eastern European Restaurant                        Field
# 98                     Drugstore  Eastern European Restaurant
# 99                       Dog Run                   Donut Shop
# 100                    Drugstore               Farmers Market
# 101       Gluten-free Restaurant                Deli / Bodega
# 102          Dumpling Restaurant                 Dessert Shop

# %%
toronto_merged.dropna(inplace=True)

# %%
# create map
address='Toronto'
geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
